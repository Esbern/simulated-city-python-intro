# %%
def plus (a,b):
    return a +b

# %%
plus (6,8)
# Out:
# 14

# %%
a =[1,2,3]

# %%
a
# Out:
# [1, 2, 3]

# %%
type(a)
# Out:
# list

# %%
a.1
# Out:
#   Cell In[6], line 1
#     a.1
#      ^
# SyntaxError: invalid syntax

# %%
a[1]
# Out:
# 2

# %%
b ={1,2,3}

# %%
b
# Out:
# {1, 2, 3}

# %%
type(b)
# Out:
# set

# %%
b.1
# Out:
#   Cell In[11], line 1
#     b.1
#      ^
# SyntaxError: invalid syntax

# %%
a = {
    "navn" : "Esbern",
    "alder" : 63
    }

# %%
a."Navn"
# Out:
#   Cell In[17], line 1
#     a."Navn"
#       ^
# SyntaxError: invalid syntax

# %%
a.navn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 a.navn
#
# AttributeError: 'dict' object has no attribute 'navn'

# %%
a
# Out:
# {'navn': 'Esbern', 'alder': 63}

# %%
a.navn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a.navn
#
# AttributeError: 'dict' object has no attribute 'navn'

# %%
a["navn"]
# Out:
# 'Esbern'
